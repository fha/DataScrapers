# %%
import math
import numpy as np
import urllib2
import json
from time import sleep
# %matplotlib inline
import matplotlib.pylab as plt

# %%
#get the set of points in a bounding box
# Description: 
# This function takes in the bounding box of the area 
# for which we intend to crawl the APIs. The function 
# returns grid points that span the bounding box. This 
# is useful because Google Places API require a point
# to search around it.

def GetSearchPoints(boundingBox,radius):
    earthCircumfurance=2*math.pi*6371;#earth's radius
    deltaCoordinate=360*(radius/earthCircumfurance);
    minLat=np.min([boundingBox[0],boundingBox[2]]);
    minLon=np.min([boundingBox[1],boundingBox[3]]);
    maxLat=np.max([boundingBox[0],boundingBox[2]]);
    maxLon=np.max([boundingBox[1],boundingBox[3]]);

    latPoints=np.ceil(np.absolute(maxLat-minLat)/deltaCoordinate);
    lonPoints=np.ceil(np.absolute(maxLon-minLon)/deltaCoordinate);

    points=np.max([latPoints,lonPoints]);
    lat_points=np.linspace(boundingBox[0],boundingBox[2],points);
    lon_points=np.linspace(boundingBox[1],boundingBox[3],points);
 
    lat_mesh,lon_mesh=np.meshgrid(lat_points,lon_points);
    lat_points=np.ndarray.flatten(lat_mesh);
    lon_points=np.ndarray.flatten(lon_mesh);
    
    return lat_points,lon_points;

# %%
# This function does a nearby search on Google places API
# It takes a coordinate and the radius desired for search
# It returns a list of places with their features.
# for reference check: https://developers.google.com/places/web-service/search#PlaceSearchRequests
#
def fetchFromGooglePOI(point,radius,googlePlacesKEY):
    radiusInMeters=radius*1000;
    allDataFetched=False;
    data=[];
    url_='https://maps.googleapis.com/maps/api/place/nearbysearch/json?location='+str(point[0][0])+','+str(point[0][1])+'&radius='+str(radiusInMeters)+'&key='+googlePlacesKEY;

    i=1;
    while(not allDataFetched):
        #sending google a request
        response = urllib2.urlopen(url_)
        
        #getting back data in json format
        html = response.read()
        cleaned=html.replace("\n","")
        json_poi=json.loads(cleaned)
        results=json_poi['results']

        if json_poi.has_key('next_page_token'):# this means that there are more POIs to fetch, need to wait a little before sending another request
            sleep(1)
            url_='https://maps.googleapis.com/maps/api/place/nearbysearch/json?pagetoken='+str(json_poi['next_page_token'])+'&key='+str(googlePlacesKEY); 
        else:
            allDataFetched=True;
            
        if len(data)==0 and len(results)!=0:
            data=results;
        elif len(results)!=0:
            data=data+results;
            
        #remind the user that the radius was too large to gather all points    
        if i>2:
            print('Radius was too large to gathered all places at {} where there are more than {} places'.format(point,len(data)))
        i=i+1;
    return data;

# %% [markdown]
# # Step1: Generate a grid of points

# %%
#SET THE PARAMETERS FOR PLACE AND RADIUS
boundingBox=[37.874363, -122.269306,37.868859, -122.253050];
radiusOfQuery=0.3; # in km
#################################################################
#for this code to work, a google API key is needed, please register 
# and enable the google places api for your account
# https://developers.google.com/maps/documentation/javascript/get-api-key
googlePlacesKEY='AIzaSyCRCYMItlzMipkpEifTRHGNLaGAR90Vpfc'
#################################################################


#this generates grid points radius meters apart
lat,lon=GetSearchPoints(boundingBox,radiusOfQuery);
print("number of points in the grid are {}".format(len(lat)))
# Out:
# number of points in the grid are 49

# %% [markdown]
# # Step2: Query Google API for every point

# %%
#This starts crawling Google API
#This code could take a while
#to test the code you can set below QueryLimit
#This will limit the number of sent queries and finish faster
QueryLimit=-1; #negative means query all points

data={}
inc=0;
for i in range(0,len(lat)):
    pointCoordinate=[tuple([lat[i],lon[i]])];
    queryResults=fetchFromGooglePOI(pointCoordinate,radiusOfQuery,googlePlacesKEY);
    for place in queryResults:
        if place['place_id'] not in data:
            inc+=1;
            data[place['place_id']]=place;

    if i>QueryLimit and QueryLimit>0:
        break;
    if i%(len(lat)/10)==0:
        print ('crawled {} points of {}'.format(i,len(lat)))
print("---------")
print('done. Gathered {} POIs'.format(inc))
# Out:
# crawled 0 points of 49
# crawled 4 points of 49
# Radius was too large to gathered all places at [(37.874363000000002, -122.26659666666667)] where there are more than 40 places
# crawled 8 points of 49
# crawled 12 points of 49
# Radius was too large to gathered all places at [(37.873445666666669, -122.26388733333333)] where there are more than 40 places
# crawled 16 points of 49
# Radius was too large to gathered all places at [(37.871611000000001, -122.26388733333333)] where there are more than 40 places
# Radius was too large to gathered all places at [(37.869776333333334, -122.26388733333333)] where there are more than 40 places
# crawled 20 points of 49
# Radius was too large to gathered all places at [(37.874363000000002, -122.261178)] where there are more than 40 places
# Radius was too large to gathered all places at [(37.872528333333335, -122.261178)] where there are more than 40 places
# crawled 24 points of 49
# Radius was too large to gathered all places at [(37.870693666666668, -122.261178)] where there are more than 40 places
# Radius was too large to gathered all places at [(37.868859, -122.261178)] where there are more than 40 places
# crawled 28 points of 49
# crawled 32 points of 49
# crawled 36 points of 49
# crawled 40 points of 49
# crawled 44 points of 49
# crawled 48 points of 49
# ---------
# done. Gathered 321 POIs

# %% [markdown]
# # Step3: Save the data to JSON file

# %%
#set the name of the file as you see fit
with open('BerkeleyPlaces.json', 'w') as fp:
    json.dump(data, fp)

# %% [markdown]
# # Viewing the crawled data: viewing places names

# %%
#this prints the names of places gathered from Google API
for a in data:
    print(data[a]['name'])
# Out:
# Stadium Garage (Impark)
# Heyday
# University of California, Berkeley Libraries
# Caffè Strada
# Hearst Mining Circle
# Chapel of St Demetrios
# Evans Diamond
# Edwards Stadium
# Koret Visitor Center
# University Health Services: Plum Carole M
# Menchie's Frozen Yogurt. Berkeley’s Only Self Serve Frozen Yogurt
# Beta Lounge
# The Magnes Collection of Jewish Art and Life
# Blow Salon
# California Memorial Stadium
# Hertz Hall
# roundCorner, Inc
# Doe Memorial Library
# Cultivating Capital
# Institute of Salesian Studies at Don Bosco Hall
# Yogurt Park
# K Street Flats
# Urbann Turbann
# Hotel Shattuck Plaza
# South Hall
# Cinnaholic
# REALM Middle School
# Half Price Books
# Berkeley Law Admissions Office
# Charles Schwab
# Downtown Berkeley Inn
# Taste of the Himalayas
# Hearst Tennis Courts
# Cal1 Card Office
# Copy Central Square
# Pimentel Hall
# Northside Cafe
# CREAM Berkeley
# Graduate School of Education
# SOD Treatment Training
# California Jazz Conservatory
# Nash Hotel
# Birge Hall
# Haas School of Business
# International House Cafe
# Berkeley Espresso
# Julia's Restaurant
# Bay Area Writing Project
# Replica Digital Ink
# Euclid Hall
# Police Review Commission
# La Val's Pizza
# Department of Plant & Microbial Biology
# Chipotle Mexican Grill
# University of California, Berkeley English Department
# Landmark's California Theatre
# Pacific School of Religion
# Stanley A. Klein Vision Laboratory
# Oldham Engineering
# Enterprise Rent-A-Car
# Starbucks
# Cal Alumni Association
# Matthew Luskin (lab/office)
# Memorial Glade
# Café Zeb
# New Bridge Foundation
# UC Hair Salon and Waxing
# Bedeian Katherine
# Berkeley Early Learning Lab
# McDonald's
# FEM Talks Women's Events
# Orthodox Institute
# Springer Gateway
# Dale Oxley Hair Salon
# Angeline's Louisiana Kitchen
# Party Sushi
# Henry H Wheeler Jr. Brain Imaging Center
# Northside
# The Marsh Arts Center
# Nelson Brittany N OD
# Berkeley
# C. V. Starr East Asian Library
# McLaughlin Hall
# Bodle Barbara
# Multinational Exchange for Sustainable Agriculture (MESA)
# The Bancroft Library
# Ink Stone
# Berkeley Apartments - Berkeleyan
# Marvell Nanofabrication Laboratory
# Vick Copy
# Moffitt Library
# Dr. Julio N. Ozores, MD
# United Artists Berkeley 7
# North Berkeley
# The Borneo Project
# University Herbarium
# Smart Mart
# Papa John's Pizza
# Human Evolution Research Center
# Berkeley Northside Travel
# Richard & Rhoda Goldman School
# NERSC - National Energy Research Scientific Computing Center
# LeConte Hall
# Lower Sproul Plaza
# Strombeck Tracey J OD
# Museum of Paleontology
# Knight Robert T MD
# Susan Sonoda, PT
# Mechanical Engineering Department
# Earth Science & Map Library
# Chemistry and Chemical Engineering Library
# Henry's
# Freight & Salvage Coffeehouse
# UC Berkeley Seismological Lab
# Bank of the West - ATM
# Micro Yali's
# Jasmine Thai
# University Health Services: Light Susan B
# Tolman Hall
# Kip's Restaurant
# Davis Hall
# Saturn Cafe Berkeley
# Babette Cafe
# Corso
# Foothill Cub Market
# 24 Hour Fitness
# Institute of Transportation Studies
# Hi-Times
# Donner Laboratory
# Brewed Awakening
# Graduate Theological Union
# LBNL Cafeteria, Bay View Cafe
# Graduate Berkeley
# Yoga to the People
# Institute of Governmental Studies Library
# Top Dog
# WHELANS GLASS GALLERY, VAPOR, CIGAR, GIFT & SMOKE SHOP
# Mike's Bikes of Berkeley
# Vaya Adventures
# Bank of America Financial Center
# Berkeley Student Cooperative - Central Office
# QB3 Berkeley
# Celtic Inheritance | MacManus and Sons Celtic Jewelers
# Walgreens
# Citibank
# Geospatial Innovation Facility (GIF)
# Emch Andrew J OD
# Stuffed Inn
# University Health Services: Stoller Valerie
# Chang Annie Y OD
# Southside
# Daiso Japan
# Meredith W. Morgan University Eye Center
# McCone Hall
# Institute of Transportation Library
# Blueprint LSAT Preparation
# International House at UC Berkeley
# Church Divinity School Of The Pacific
# La Burrita
# Games of Berkeley
# Inveneo
# Department of Ethnic Studies
# Comal
# UC Berkeley School of Optometry Professional Program
# UC Berkeley Extension
# Cal Copy
# Bongo Burger
# Morgan Hall
# Career Development Office-Berkeley
# Scandinavian Designs
# C U Japanese Fusion
# Lara Summer G OD
# Noah's Bagels
# Café Rio
# Bay Area Writing Project
# Downtown Berkeley
# Oxford Property Management, Berkeley, CA
# Museum of Vertebrate Zoology
# Pi Beta Phi Sorority
# Office of Undergraduate Admissions
# Cal Berkeley Reads
# Haas Pavilion
# Abe's Pizza
# East Bay Spice Company
# Downtown Berkeley YMCA
# Maxwell Family Field
# Optometry School Administration: Yeh Thao N OD
# Wellman Courtyard Parking
# Polonenko Tanya M OD
# Veronique L. Thompson, PHD
# 42, Inc.
# UCB Educational Tech Services
# United States Postal Service
# University Press Books
# Golden Bear Café
# Women's Faculty Club
# Party Heaven
# Lewis Hall
# Senior Hall
# Hans Jenny Pygmy Forrest
# Gary Eason - State Farm Insurance Agent
# Berkeley Public Library
# Raj Properties
# Regents of the University of Ca
# California Hall
# Au Coquelet
# The Sunny Side Café
# Durham Studio Theater
# Nyingma Institute Buddhist Center
# Stern Hall
# Aki's Japanese Restaurant
# 70
# College of Environmental Design
# Berkeley Mail Center
# Urban Outfitters
# Valley Life Sciences Building
# Berkeley Art Studio
# Blue Sky Hotel
# Berkeley Geochronolgy Center
# Bay Area Open Space Council
# Celia's Mexican Restaurant
# Free House
# Fat Slice Pizza
# Berkeley City Club
# Spa Dog Botanicals
# Revival Bar + Kitchen
# Physics-Astronomy Library
# Sproul Hall
# Bank of America Financial Center
# Action Alliance For Children
# Berkeley Police Association
# The Greek Theatre
# Wright Institute
# Gather
# Lhasa Karnak Herb Company
# Campbell Hall
# Blum Center for Developing Economies
# Kristen Rasmussen, RD
# Tipping Structural Engineers
# Art History/Classics Library
# Hillside Village Apartments
# Berkeley Student Cooperative - Casa Zimbabwe Student Housing Co-op
# University Health Services: Ratliff Mpho M
# Lazer Image Printing-Graphics
# Dr. Guy G. Micco, MD
# David Brower Center
# Archaeological Research Facility
# Pappy's Grill & Sports Bar
# Campus Store
# Bear's Lair Tavern
# Matteo Garbelotto Lab
# Department of Mathematics
# Essig Museum-Entomology Research
# University Health Services-Tang Center
# University Park Apartments
# Bancroft Hotel
# Bancroft Clothing Co
# UC Berkeley: Upper Sproul Plaza
# Optometry School Administration: Jonasson Heather Eli OD
# 70A
# Media Relations - Cal Athletic Communications
# Berkeley Community Theater
# Crossroads Trading
# Dharma Publishing Bookstore
# YWCA Berkeley/Oakland
# Memorial Pool
# Teaching Library
# Missing Link Bicycle Cooperative
# Electron Microscope Lab
# Landmark's Shattuck Cinemas
# University of California Police Department
# Wheeler Hall Auditorium
# Optometry Library
# Bachenheimer Apartments
# Artistic Picture Framing
# Ippuku
# United States Postal Service
# University Hall
# Brown's California Café
# Berkeley Graduate School of Journalism
# Triple Rock Brewing
# Berkeley Hillel
# Cal Performances
# Annice Ormiston, PsyD
# Model Shoe Renew
# Yogurtland
# Robert B. Greer, OD
# Department of Nutritional Science and Toxicology
# East Bay Sanctuary Covenant
# Jupiter
# Disabled Students' Program
# UC Berkeley Library Data Lab
# University Health Services: Sommer Vicki L
# Fix That Mac
# Zee Zee Copy
# Bongo Burger
# Stanley Hall
# ESnet - Energy Sciences Network
# Sumito's Floral Design
# Delta Chi - Abracadabra Chapter
# Hilgard Hall
# The Musical Offering Cafe
# Panoramic Management
# Brazil Cafe
# Yali's Café
# University of California, Berkeley
# AT&T Store
# The Noodle Thai Restaurant
# Moran Engineering, Inc.
# The Coffee Lab
# Riverstone Resolutions, LLC
# Montessori Family School: Preschool-Kindergarten
# School of Information
# Subway Restaurants
# Café Milano
# Building 50B
# Greenlining Institute - Casa Joaquin House
# Center for Nonprofit and Public Leadership
# Social Research Library
# Eudemonia
# Downtown Berkeley Station
